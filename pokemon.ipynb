# %%
# importamos las librerías necesarias 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

from matplotlib.pyplot import rcParams

rcParams['figure.figsize'] = 12, 6 # el primer dígito es el ancho y el segundo el alto
rcParams["font.weight"] = "bold"
rcParams["font.size"] = 10
rcParams["axes.labelweight"] = "bold"

# Cargamos el dataset
import pandas as pd
import chardet

file_path = 'Pokemon Go - prueba\pokemon.csv'
with open(file_path, "rb") as f:
    result = chardet.detect(f.read())

# Leer el archivo CSV utilizando la codificación detectada
df_pokemon = pd.read_csv(file_path, encoding=result["encoding"], on_bad_lines="skip")

# Mostrar las primeras filas del DataFrame
df_pokemon.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 20
#      17 import chardet
#      19 file_path = 'Pokemon Go - prueba\pokemon.csv'
# ---> 20 with open(file_path, "rb") as f:
#      21     result = chardet.detect(f.read())
#      23 # Leer el archivo CSV utilizando la codificación detectada
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Pokemon Go - prueba\\pokemon.csv'
